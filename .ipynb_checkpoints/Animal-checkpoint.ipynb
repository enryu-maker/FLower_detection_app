# %%
import tensorflow as tf
from tensorflow.python.compiler.mlcompute import mlcompute
mlcompute.set_mlc_device(device_name='any')
tf.compat.v1.disable_eager_execution()
print(tf.__version__)
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2.4.0-rc0

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(128,(3,3),activation='relu',input_shape=(28,28,3)),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dense(4,activation='softmax')
])

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(
loss=tf.keras.losses.categorical_crossentropy,
optimizer='adam',
metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
Generator=ImageDataGenerator(validation_split=0.2,rescale=1/255)
train_gen=Generator.flow_from_directory(
'./animal/',
target_size=(28,28),
batch_size=64,
class_mode='categorical',
subset='training')

val_generator = Generator.flow_from_directory(
    './animal',
    target_size=(28,28),
    batch_size=64,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 8482 images belonging to 4 classes.
# Found 2118 images belonging to 4 classes.

# %%
history=model.fit(train_gen,
                  steps_per_epoch=8,
                  validation_data=train_gen,
                  validation_steps=8,
                  epochs=15,
                  verbose=1)
# Out:
# Epoch 1/15
# 8/8 [==============================] - ETA: 0s - batch: 3.5000 - size: 64.0000 - loss: 1.2539 - accuracy: 0.4414
# /opt/homebrew/Caskroom/miniforge/base/envs/tensor_flow/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 8/8 [==============================] - 2s 171ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2539 - accuracy: 0.4414 - val_loss: 1.3626 - val_accuracy: 0.4160
# Epoch 2/15
# 8/8 [==============================] - 1s 122ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.1956 - accuracy: 0.5176 - val_loss: 1.3535 - val_accuracy: 0.4160
# Epoch 3/15
# 8/8 [==============================] - 1s 120ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2575 - accuracy: 0.4629 - val_loss: 1.3052 - val_accuracy: 0.4160
# Epoch 4/15
# 8/8 [==============================] - 1s 125ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2430 - accuracy: 0.4785 - val_loss: 1.3106 - val_accuracy: 0.4160
# Epoch 5/15
# 8/8 [==============================] - 1s 121ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2482 - accuracy: 0.4668 - val_loss: 1.2949 - val_accuracy: 0.4160
# Epoch 6/15
# 8/8 [==============================] - 1s 121ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2538 - accuracy: 0.4414 - val_loss: 1.3016 - val_accuracy: 0.4160
# Epoch 7/15
# 8/8 [==============================] - 1s 128ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2885 - accuracy: 0.4082 - val_loss: 1.2820 - val_accuracy: 0.4160
# Epoch 8/15
# 8/8 [==============================] - 1s 121ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2003 - accuracy: 0.4883 - val_loss: 1.3263 - val_accuracy: 0.4160
# Epoch 9/15
# 8/8 [==============================] - 1s 119ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2312 - accuracy: 0.4473 - val_loss: 1.2932 - val_accuracy: 0.4160
# Epoch 10/15
# 8/8 [==============================] - 1s 120ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2247 - accuracy: 0.4668 - val_loss: 1.2678 - val_accuracy: 0.4141
# Epoch 11/15
# 8/8 [==============================] - 1s 120ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2230 - accuracy: 0.4551 - val_loss: 1.2622 - val_accuracy: 0.3848
# Epoch 12/15
# 8/8 [==============================] - 1s 120ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2294 - accuracy: 0.4297 - val_loss: 1.2460 - val_accuracy: 0.4180
# Epoch 13/15
# 8/8 [==============================] - 1s 119ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.2176 - accuracy: 0.4688 - val_loss: 1.2260 - val_accuracy: 0.4199
# Epoch 14/15
# 8/8 [==============================] - 1s 119ms/step - batch: 3.5000 - size: 60.2500 - loss: 1.1627 - accuracy: 0.5187 - val_loss: 1.2369 - val_accuracy: 0.4258
# Epoch 15/15
# 8/8 [==============================] - 1s 121ms/step - batch: 3.5000 - size: 64.0000 - loss: 1.1814 - accuracy: 0.4902 - val_loss: 1.2337 - val_accuracy: 0.4316

# %%
training_loss = history.history['loss']
val_loss=history.history['val_loss']
epoch_count = range(1, len(training_loss) + 1)

# %%
plt.plot(epoch_count, training_loss, 'r')
plt.plot(epoch_count, val_loss, 'g')
plt.title('loss vs epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %%
training_acc = history.history['accuracy']
val_acc=history.history['val_accuracy']
epoch_count = range(1, len(training_loss) + 1)

# %%
plt.plot(epoch_count, training_acc, 'r')
plt.plot(epoch_count, val_acc, 'g')
plt.title('accuracy vs epoch')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.show();
