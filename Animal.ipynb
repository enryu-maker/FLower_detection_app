# %%
import tensorflow as tf
from tensorflow.python.compiler.mlcompute import mlcompute
mlcompute.set_mlc_device(device_name='gpu')
tf.compat.v1.disable_eager_execution()
print(tf.__version__)
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2.4.0-rc0

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(128,(3,3),activation='relu',input_shape=(28,28,3)),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Conv2D(32,(3,3),activation='relu'),
    tf.keras.layers.MaxPool2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(64,activation='relu'),
    tf.keras.layers.Dense(4,activation='softmax')
])

# %%
from tensorflow.keras.optimizers import RMSprop
model.compile(
loss=tf.keras.losses.categorical_crossentropy,
optimizer='adam',
metrics=['accuracy'])

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
Generator=ImageDataGenerator(validation_split=0.2,rescale=1/255)
train_gen=Generator.flow_from_directory(
'./animal/',
target_size=(28,28),
batch_size=64,
class_mode='categorical',
subset='training')

val_generator = Generator.flow_from_directory(
    './animal',
    target_size=(28,28),
    batch_size=64,
    class_mode='categorical',
    subset='validation'
)
# Out:
# Found 8482 images belonging to 4 classes.
# Found 2118 images belonging to 4 classes.

# %%
history=model.fit(train_gen,
                  steps_per_epoch=210,
                  validation_data=train_gen,
                  validation_steps=100,
                  epochs=15,
                  verbose=1)
# Out:
# Epoch 1/15
# 210/210 [==============================] - ETA: 0s - batch: 104.5000 - size: 63.8571 - loss: 1.2234 - accuracy: 0.4771
# /opt/homebrew/Caskroom/miniforge/base/envs/tensor_flow/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 210/210 [==============================] - 28s 133ms/step - batch: 104.5000 - size: 63.8571 - loss: 1.2234 - accuracy: 0.4771 - val_loss: 1.0951 - val_accuracy: 0.5430
# Epoch 2/15
# 210/210 [==============================] - 28s 132ms/step - batch: 104.5000 - size: 63.5714 - loss: 1.0367 - accuracy: 0.5669 - val_loss: 1.0190 - val_accuracy: 0.5813
# Epoch 3/15
# 210/210 [==============================] - 27s 128ms/step - batch: 104.5000 - size: 63.8571 - loss: 0.9210 - accuracy: 0.6230 - val_loss: 0.8971 - val_accuracy: 0.6306
# Epoch 4/15
# 210/210 [==============================] - 28s 133ms/step - batch: 104.5000 - size: 63.8571 - loss: 0.8488 - accuracy: 0.6496 - val_loss: 0.7911 - val_accuracy: 0.6778
# Epoch 5/15
# 210/210 [==============================] - 27s 129ms/step - batch: 104.5000 - size: 63.7143 - loss: 0.7943 - accuracy: 0.6701 - val_loss: 0.7056 - val_accuracy: 0.7034
# Epoch 6/15
# 210/210 [==============================] - 27s 131ms/step - batch: 104.5000 - size: 63.7143 - loss: 0.7182 - accuracy: 0.7018 - val_loss: 0.6806 - val_accuracy: 0.7144
# Epoch 7/15
# 210/210 [==============================] - 27s 130ms/step - batch: 104.5000 - size: 63.7143 - loss: 0.6698 - accuracy: 0.7200 - val_loss: 0.5951 - val_accuracy: 0.7653
# Epoch 8/15
# 210/210 [==============================] - 26s 126ms/step - batch: 104.5000 - size: 63.8571 - loss: 0.5998 - accuracy: 0.7551 - val_loss: 0.5282 - val_accuracy: 0.7833
# Epoch 9/15
# 210/210 [==============================] - 27s 131ms/step - batch: 104.5000 - size: 63.8571 - loss: 0.5528 - accuracy: 0.7773 - val_loss: 0.4918 - val_accuracy: 0.8130
# Epoch 10/15
# 210/210 [==============================] - 28s 133ms/step - batch: 104.5000 - size: 63.7143 - loss: 0.4975 - accuracy: 0.7970 - val_loss: 0.4348 - val_accuracy: 0.8359
# Epoch 11/15
# 210/210 [==============================] - 28s 135ms/step - batch: 104.5000 - size: 63.8571 - loss: 0.4333 - accuracy: 0.8286 - val_loss: 0.3535 - val_accuracy: 0.8742
# Epoch 12/15
# 210/210 [==============================] - 27s 131ms/step - batch: 104.5000 - size: 63.7143 - loss: 0.3839 - accuracy: 0.8484 - val_loss: 0.3114 - val_accuracy: 0.8870
# Epoch 13/15
# 210/210 [==============================] - 28s 133ms/step - batch: 104.5000 - size: 63.7143 - loss: 0.3207 - accuracy: 0.8735 - val_loss: 0.2396 - val_accuracy: 0.9152
# Epoch 14/15
# 210/210 [==============================] - 28s 133ms/step - batch: 104.5000 - size: 63.7143 - loss: 0.3062 - accuracy: 0.8783 - val_loss: 0.2830 - val_accuracy: 0.8894
# Epoch 15/15
# 210/210 [==============================] - 27s 130ms/step - batch: 104.5000 - size: 63.8571 - loss: 0.2428 - accuracy: 0.9088 - val_loss: 0.1682 - val_accuracy: 0.9375

# %%
training_loss = history.history['loss']
val_loss=history.history['val_loss']
epoch_count = range(1, len(training_loss) + 1)

# %%
plt.plot(epoch_count, training_loss, 'r')
plt.plot(epoch_count, val_loss, 'g')
plt.title('loss vs epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show();

# %%
training_acc = history.history['accuracy']
val_acc=history.history['val_accuracy']
epoch_count = range(1, len(training_loss) + 1)

# %%
plt.plot(epoch_count, training_acc, 'r')
plt.plot(epoch_count, val_acc, 'g')
plt.title('accuracy vs epoch')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.show();
